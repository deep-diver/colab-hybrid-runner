# %% [markdown]
# # Auto-Generated Clean Pipeline Notebook
# This notebook contains pure cell logic without any hybrid/handover code.

# %% [markdown]
# ### Step: `step1_prepare_data` (Target: local)

# %%
def step1_prepare_data():
    print("Preparing vector data locally...")
    x = torch.tensor([10.0, 20.0, 30.0, 40.0])
    return x

# %% [markdown]
# ### Step: `step2_gpu_compute` (Target: remote)

# %%
def step2_gpu_compute(x):
    # Pure PyTorch logic on GPU (Zero handover clutter!)
    print(f"Colab GPU received tensor: {x}")
    result = x * 2.5 + 100.0
    return result

# %% [markdown]
# ### Step: `step3_local_result` (Target: local)

# %%
def step3_local_result(res):
    print("Received computation result on local CPU:")
    print(res)
    return res
